# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# From https://pytorch.org/docs/0.3.1/nn.html?highlight=crossentropy#bcewithlogitsloss
#
# This loss combines a Sigmoid layer and the BCELoss in one single class. This version is more numerically stable than using a plain Sigmoid followed by a BCELoss as, by combining the operations into one layer, we take advantage of the log-sum-exp trick for numerical stability.
#
# The loss can be described as:
# ℓ(x,y)=L={l1,…,lN}⊤,ln=−wn[tn⋅logσ(xn)+(1−tn)⋅log(1−σ(xn))],
#
# where N
#
# is the batch size. If reduce is True, then
# ℓ(x,y)={mean(L),sum(L),ifsize_average=True,ifsize_average=False.
#
# This is used for measuring the error of a reconstruction in for example an auto-encoder. Note that the targets t[i] should be numbers between 0 and 1.
# Parameters:
#
#     weight (Tensor, optional) – a manual rescaling weight given to the loss of each batch element. If given, has to be a Tensor of size “nbatch”.
#     size_average – By default, the losses are averaged over observations for each minibatch. However, if the field size_average is set to False, the losses are instead summed for each minibatch. Default: True

# %%
from Where import *
# Out:
# Loading accuracy... min, max= 0.0145 0.9852

# %% [markdown]
# ## Réseau de neurones

# %% [markdown]
# ### Lancer l'apprentissage ou charger les données

# %%
path = '2018-05-31_classification_BCELoss_.pt'

# %%
# !ls -l {path}
#!rm {path}
# Out:
# -rw-r--r--  1 laurentperrinet  staff  5093285 May 31 17:02 2018-05-31_classification_BCELoss_.pt

# %%
if os.path.isfile(path):
    net.load_state_dict(torch.load(path))
    print('Loading file', path)
else:
    print('Training model...')
    N_epochs = 15
    for epoch in range(N_epochs):          #max number of training epochs
        net = train(net, minibatch_size)                 #starting the learning
        torch.save(net.state_dict(), path) #save the neural network state
        print('Model saved at', path)
# Out:
# Training model...
# Starting training...
# [0/60000] Loss: 0.6941103935241699 Time: 0.02 mn
# [10000/60000] Loss: 0.6396048665046692 Time: 1.57 mn
# [20000/60000] Loss: 0.39346370100975037 Time: 3.20 mn
# [30000/60000] Loss: 0.37263163924217224 Time: 4.83 mn
# [40000/60000] Loss: 0.3686301112174988 Time: 6.46 mn
# [50000/60000] Loss: 0.3705243468284607 Time: 8.09 mn
# Model saved at 2018-05-31_classification_BCELoss_.pt
# Starting training...
# [0/60000] Loss: 0.3726907968521118 Time: 0.01 mn
# [10000/60000] Loss: 0.3688640892505646 Time: 1.36 mn
# [20000/60000] Loss: 0.3675033450126648 Time: 2.88 mn
# [30000/60000] Loss: 0.37352609634399414 Time: 4.41 mn
# [40000/60000] Loss: 0.3696913719177246 Time: 5.93 mn
# [50000/60000] Loss: 0.3653801381587982 Time: 7.46 mn
# Model saved at 2018-05-31_classification_BCELoss_.pt
# Starting training...
# [0/60000] Loss: 0.3653188645839691 Time: 0.02 mn
# [10000/60000] Loss: 0.3676321804523468 Time: 1.53 mn
# [20000/60000] Loss: 0.3679637014865875 Time: 3.04 mn
# [30000/60000] Loss: 0.3768567144870758 Time: 4.56 mn
# [40000/60000] Loss: 0.36786672472953796 Time: 6.08 mn
# [50000/60000] Loss: 0.36672958731651306 Time: 7.60 mn
# Model saved at 2018-05-31_classification_BCELoss_.pt
# Starting training...
# [0/60000] Loss: 0.3691488802433014 Time: 0.02 mn
# [10000/60000] Loss: 0.3695376217365265 Time: 1.53 mn
# [20000/60000] Loss: 0.367814302444458 Time: 3.04 mn
# [30000/60000] Loss: 0.36951905488967896 Time: 4.55 mn
# [40000/60000] Loss: 0.3705199062824249 Time: 6.06 mn
# [50000/60000] Loss: 0.36457014083862305 Time: 7.58 mn
# Model saved at 2018-05-31_classification_BCELoss_.pt
# Starting training...
# [0/60000] Loss: 0
mn
# Model saved at 2018-05-31_classification_BCELoss_.pt
# Starting training...
# [0/60000] Loss: 0.36139073967933655 Time: 0.01 mn
# [10000/60000] Loss: 0.36234837770462036 Time: 1.44 mn
# [20000/60000] Loss: 0.3650759160518646 Time: 2.86 mn
# [30000/60000] Loss: 0.363385409116745 Time: 4.28 mn
# [40000/60000] Loss: 0.3650180995464325 Time: 5.65 mn
# [50000/60000] Loss: 0.363750696182251 Time: 6.96 mn
# Model saved at 2018-05-31_classification_BCELoss_.pt

# %% [markdown]
# ### Lancer l'évaluation

# %%
N_test = 10

for _ in range(N_test):
    eval_sacc()
    plt.show()
# Out:
# Stimulus position: (5,-4)
# Position prediction: (3.0,-6.0)
# **************************************************
# Stimulus position: (-5,-2)
# Position prediction: (-6.0,-1.0)
# **************************************************
# Stimulus position: (2,0)
# Position prediction: (2.0,-5.0)
# **************************************************
# Stimulus position: (-10,-2)
# Position prediction: (-6.0,-1.0)
# **************************************************
# Stimulus position: (5,-9)
# Position prediction: (2.0,-7.0)
# **************************************************
# Stimulus position: (-1,-13)
# Position prediction: (0.0,-10.0)
# **************************************************
# Stimulus position: (6,13)
# Position prediction: (2.0,7.0)
# **************************************************
# Stimulus position: (8,0)
# Position prediction: (4.0,-1.0)
# **************************************************
# Stimulus position: (-2,1)
# Position prediction: (1.0,-4.0)
# **************************************************
# Stimulus position: (16,-8)
# Position prediction: (13.0,-5.0)
# **************************************************

# %%
for _ in range(N_test):
    eval_sacc(fig_type='log')
    plt.show()
# Out:
# Stimulus position: (-1,1)
# Loading pred_data... min, max= 0.09573327 0.36041918
# a_data position (log_r, azimuth) = (-0.10903548889591241,0.7853981633974483)
# **************************************************
# Stimulus position: (9,14)
# Loading pred_data... min, max= 0.07630664 0.1680266
# a_data position (log_r, azimuth) = (0.3840515436668268,-0.5713374798336268)
# **************************************************
# Stimulus position: (5,19)
# Loading pred_data... min, max= 0.07170708 0.13694423
# a_data position (log_r, azimuth) = (0.41723352999457597,-0.25732371497108864)
# **************************************************
# Stimulus position: (-16,12)
# Loading pred_data... min, max= 0.064537704 0.13493147
# a_data position (log_r, azimuth) = (0.42079624775889113,0.9272952180016122)
# **************************************************
# Stimulus position: (-2,-17)
# Loading pred_data... min, max= 0.078581676 0.14613107
# a_data position (log_r, azimuth) = (0.3896670539497997,-0.11710874456686428)
# **************************************************
# Stimulus position: (6,-4)
# Loading pred_data... min, max= 0.089202255 0.32364118
# a_data position (log_r, azimuth) = (0.2167741649062357,0.982793723247329)
# **************************************************
# Stimulus position: (0,7)
# Loading pred_data... min, max= 0.07902035 0.3926145
# a_data position (log_r, azimuth) = (0.21083182285915558,0.0)
# **************************************************
# Stimulus position: (-3,-5)
# Loading pred_data... min, max= 0.08517247 0.31407937
# a_data position (log_r, azimuth) = (0.17428584550970905,-0.5404195002705842)
# **************************************************
# Stimulus position: (0,16)
# Loading pred_data... min, max= 0.06625819 0.18367273
# a_data position (log_r, azimuth) = (0.37616753749604925,0.0)
# **************************************************
# Stimulus position: (-10,8)
# Loading pred_data... min, max= 0.08605248 0.21508859
# a_data position (log_r, azimuth) = (0.33163643583051283,0.8960553845713439)
# **************************************************
