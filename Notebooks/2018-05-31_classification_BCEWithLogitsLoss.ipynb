# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# From https://pytorch.org/docs/0.3.1/nn.html?highlight=crossentropy#bcewithlogitsloss
#
# This loss combines a Sigmoid layer and the BCELoss in one single class. This version is more numerically stable than using a plain Sigmoid followed by a BCELoss as, by combining the operations into one layer, we take advantage of the log-sum-exp trick for numerical stability.
#
# The loss can be described as:
# ℓ(x,y)=L={l1,…,lN}⊤,ln=−wn[tn⋅logσ(xn)+(1−tn)⋅log(1−σ(xn))],
#
# where N
#
# is the batch size. If reduce is True, then
# ℓ(x,y)={mean(L),sum(L),ifsize_average=True,ifsize_average=False.
#
# This is used for measuring the error of a reconstruction in for example an auto-encoder. Note that the targets t[i] should be numbers between 0 and 1.
# Parameters:
#
#     weight (Tensor, optional) – a manual rescaling weight given to the loss of each batch element. If given, has to be a Tensor of size “nbatch”.
#     size_average – By default, the losses are averaged over observations for each minibatch. However, if the field size_average is set to False, the losses are instead summed for each minibatch. Default: True

# %%
from Where import *
# Out:
# Loading accuracy... min, max= 0.0145 0.9852

# %% [markdown]
# ## Réseau de neurones

# %% [markdown]
# ### Lancer l'apprentissage ou charger les données

# %%
path = '2018-06-05_classification_BCELoss_.pt'

# %%
# !ls -l {path}
#!rm {path}
# Out:
# ls: cannot access '2018-06-05_classification_BCELoss_.pt': No such file or directory

# %%
if os.path.isfile(path):
    net.load_state_dict(torch.load(path))
    print('Loading file', path)
else:
    print('Training model...')
    N_epochs = 5
    for epoch in range(N_epochs):          #max number of training epochs
        net = train(net, minibatch_size)                 #starting the learning
        torch.save(net.state_dict(), path) #save the neural network state
        print('Model saved at', path)
# Out:
# Loading file 2018-06-05_classification_BCELoss_.pt

# %% [markdown]
# ### Lancer l'évaluation

# %%
N_test = 10

for _ in range(N_test):
    eval_sacc()
    plt.show()
# Out:
# Stimulus position: (25,-12)
# Position prediction: (-27.0,5.0)
# **************************************************
# Stimulus position: (-2,-5)
# Position prediction: (4.0,13.0)
# **************************************************
# Stimulus position: (0,15)
# Position prediction: (18.0,9.0)
# **************************************************
# Stimulus position: (18,11)
# Position prediction: (28.0,-6.0)
# **************************************************
# Stimulus position: (-4,7)
# Position prediction: (33.0,23.0)
# **************************************************
# Stimulus position: (2,-3)
# Position prediction: (17.0,11.0)
# **************************************************
# Stimulus position: (1,24)
# Position prediction: (18.0,9.0)
# **************************************************
# Stimulus position: (-3,-13)
# Position prediction: (-14.0,-4.0)
# **************************************************
# Stimulus position: (-1,2)
# Position prediction: (17.0,10.0)
# **************************************************
# Stimulus position: (-17,0)
# Position prediction: (38.0,-3.0)
# **************************************************

# %%
for _ in range(N_test):
    eval_sacc(fig_type='log')
    plt.show()
# Out:
# Stimulus position: (1,24)
# Loading pred_data... min, max= 0.022940954 0.9756089
# a_data position (log_r, azimuth) = (0.45743401969890285,-0.04164257909858842)
# **************************************************
# Stimulus position: (-5,-2)
# Loading pred_data... min, max= 0.061153583 0.8933815
# a_data position (log_r, azimuth) = (0.15837937604674024,-1.1902899496825317)
# **************************************************
# Stimulus position: (-14,9)
# Loading pred_data... min, max= 0.019936511 0.9732281
# a_data position (log_r, azimuth) = (0.3840515436668268,0.9994588469612699)
# **************************************************
# Stimulus position: (0,-17)
# Loading pred_data... min, max= 0.11524109 0.8898348
# a_data position (log_r, azimuth) = (0.3882924618593362,-0.0)
# **************************************************
# Stimulus position: (10,0)
# Loading pred_data... min, max= 0.03456889 0.9424212
# a_data position (log_r, azimuth) = (0.28216681164690205,-1.5707963267948966)
# **************************************************
# Stimulus position: (14,8)
# Loading pred_data... min, max= 0.035620544 0.979037
# a_data position (log_r, azimuth) = (0.37771795614964565,-1.0516502125483738)
# **************************************************
# Stimulus position: (6,9)
# Loading pred_data... min, max= 0.07333733 0.9459898
# a_data position (log_r, azimuth) = (0.2978671865278686,-0.5880026035475675)
# **************************************************
# Stimulus position: (-8,-7)
# Loading pred_data... min, max= 0.10507202 0.87737715
# a_data position (log_r, azimuth) = (0.294388574919327,-0.851966327173272)
# **************************************************
# Stimulus position: (5,9)
# Loading pred_data... min, max= 0.011796177 0.98187387
# a_data position (log_r, azimuth) = (0.28799370245929967,-0.507098504392337)
# **************************************************
# Stimulus position: (-7,-1)
# Loading pred_data... min, max= 0.08669927 0.9218795
# a_data position (log_r, azimuth) = (0.2128520935909075,-1.4288992721907328)
# **************************************************
