# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# From https://pytorch.org/docs/0.3.1/nn.html?highlight=crossentropy#bcewithlogitsloss
#
# This loss combines a Sigmoid layer and the BCELoss in one single class. This version is more numerically stable than using a plain Sigmoid followed by a BCELoss as, by combining the operations into one layer, we take advantage of the log-sum-exp trick for numerical stability.
#
# The loss can be described as:
# ℓ(x,y)=L={l1,…,lN}⊤,ln=−wn[tn⋅logσ(xn)+(1−tn)⋅log(1−σ(xn))],
#
# where N
#
# is the batch size. If reduce is True, then
# ℓ(x,y)={mean(L),sum(L),ifsize_average=True,ifsize_average=False.
#
# This is used for measuring the error of a reconstruction in for example an auto-encoder. Note that the targets t[i] should be numbers between 0 and 1.
# Parameters:
#
#     weight (Tensor, optional) – a manual rescaling weight given to the loss of each batch element. If given, has to be a Tensor of size “nbatch”.
#     size_average – By default, the losses are averaged over observations for each minibatch. However, if the field size_average is set to False, the losses are instead summed for each minibatch. Default: True

# %%
from Where import *
# Out:
# Loading accuracy... min, max= 0.0145 0.9852

# %% [markdown]
# ## Réseau de neurones

# %% [markdown]
# ### Lancer l'apprentissage ou charger les données

# %%
path = '2018-05-31_classification_BCELoss_.pt'

# %%
# !ls -l {path}
# !rm {path}
# Out:
# ls: 2018-05-31_classification_BCELoss_.pt: No such file or directory
# rm: 2018-05-31_classification_BCELoss_.pt: No such file or directory

# %%
if os.path.isfile(path):
    net.load_state_dict(torch.load(path))
    print('Loading file', path)
else:
    print('Training model...')
    N_epochs = 3
    for epoch in range(N_epochs):          #max number of training epochs
        net = train(net, minibatch_size)                 #starting the learning
        torch.save(net.state_dict(), path) #save the neural network state
        print('Model saved at', path)
# Out:
# Training model...
# Starting training...
# [0/60000] Loss: 0.9270846843719482 Time: 0.01 mn
# [10000/60000] Loss: 0.696551501750946 Time: 1.18 mn
# [20000/60000] Loss: 0.6944950222969055 Time: 2.38 mn
# [30000/60000] Loss: 0.6939904689788818 Time: 3.58 mn
# [40000/60000] Loss: 0.6936939358711243 Time: 4.78 mn
# [50000/60000] Loss: 0.6934865117073059 Time: 6.00 mn
# Model saved at 2018-05-31_classification_BCELoss_.pt
# Starting training...
# [0/60000] Loss: 0.6935063600540161 Time: 0.01 mn
# [10000/60000] Loss: 0.693372368812561 Time: 1.24 mn
# [20000/60000] Loss: 0.6934789419174194 Time: 2.46 mn
# [30000/60000] Loss: 0.6933542490005493 Time: 3.68 mn
# [40000/60000] Loss: 0.6933817863464355 Time: 4.90 mn
# [50000/60000] Loss: 0.6932945847511292 Time: 6.13 mn
# Model saved at 2018-05-31_classification_BCELoss_.pt
# Starting training...
# [0/60000] Loss: 0.6932908296585083 Time: 0.01 mn
# [10000/60000] Loss: 0.6932670474052429 Time: 1.23 mn
# [20000/60000] Loss: 0.6932505965232849 Time: 2.45 mn
# [30000/60000] Loss: 0.6932141184806824 Time: 3.68 mn
# [40000/60000] Loss: 0.6932398676872253 Time: 4.90 mn
# [50000/60000] Loss: 0.6932469010353088 Time: 6.12 mn
# Model saved at 2018-05-31_classification_BCELoss_.pt

# %% [markdown]
# ### Lancer l'évaluation

# %%
N_test = 10

for _ in range(N_test):
    eval_sacc()
    plt.show()
# Out:
# Stimulus position: (-2,4)
# Position prediction: (-10.0,0.0)
# **************************************************
# Stimulus position: (2,11)
# Position prediction: (-4.0,-12.0)
# **************************************************
# Stimulus position: (-1,6)
# Position prediction: (-7.0,-2.0)
# **************************************************
# Stimulus position: (-18,8)
# Position prediction: (-2.0,-4.0)
# **************************************************
# Stimulus position: (22,-10)
# Position prediction: (-1.0,-19.0)
# **************************************************
# Stimulus position: (-5,11)
# Position prediction: (-4.0,13.0)
# **************************************************
# Stimulus position: (3,-20)
# Position prediction: (-9.0,10.0)
# **************************************************
# Stimulus position: (-5,-5)
# Position prediction: (2.0,7.0)
# **************************************************
# Stimulus position: (-6,3)
# Position prediction: (-9.0,1.0)
# **************************************************
# Stimulus position: (9,18)
# Position prediction: (25.0,9.0)
# **************************************************

# %%
for _ in range(N_test):
    eval_sacc(fig_type='log')
    plt.show()
# Out:
# Stimulus position: (-16,14)
# (96,)
# Loading pred_data... min, max= 2.048017e-05 0.0020243332
# a_data position (log_r, azimuth) = (0.4330180110313161,0.851966327173272)
# **************************************************
# Stimulus position: (7,0)
# (96,)
# Loading pred_data... min, max= 2.1723427e-08 2.607307e-06
# a_data position (log_r, azimuth) = (0.21083182285915558,-1.5707963267948966)
# **************************************************
# Stimulus position: (5,-1)
# (96,)
# Loading pred_data... min, max= 2.0693408e-07 2.3249255e-05
# a_data position (log_r, azimuth) = (0.14745944685024115,1.373400766945016)
# **************************************************
# Stimulus position: (0,-15)
# (96,)
# Loading pred_data... min, max= 8.14585e-09 4.8282473e-05
# a_data position (log_r, azimuth) = (0.36325983326853495,-0.0)
# **************************************************
# Stimulus position: (13,-9)
# (96,)
# Loading pred_data... min, max= 7.61062e-06 0.0008762731
# a_data position (log_r, azimuth) = (0.3737958848343176,0.9652516631899266)
# **************************************************
# Stimulus position: (17,-5)
# (96,)
# Loading pred_data... min, max= 3.0374327e-09 6.809524e-06
# a_data position (log_r, azimuth) = (0.3965890916389183,1.2847448850775784)
# **************************************************
# Stimulus position: (16,-2)
# (96,)
# Loading pred_data... min, max= 1.0345215e-08 7.5761645e-06
# a_data position (log_r, azimuth) = (0.37771795614964565,1.446441332248135)
# **************************************************
# Stimulus position: (-9,-5)
# (96,)
# Loading pred_data... min, max= 8.399399e-08 2.890011e-05
# a_data position (log_r, azimuth) = (0.28799370245929967,-1.0636978224025597)
# **************************************************
# Stimulus position: (1,-20)
# (96,)
# Loading pred_data... min, max= 3.8298685e-06 0.0009179115
# a_data position (log_r, azimuth) = (0.42104593577874994,0.049958395721942765)
# **************************************************
# Stimulus position: (14,-4)
# (96,)
# Loading pred_data... min, max= 1.234792e-05 0.0005229204
# a_data position (log_r, azimuth) = (0.3573084205152942,1.2924966677897853)
# **************************************************
