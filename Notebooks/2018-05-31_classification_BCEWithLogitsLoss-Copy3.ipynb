# %%
# %load_ext autoreload
# %autoreload 2

# %%
from Where_test_couples import *
# Out:
# Loading accuracy... min, max= 0.0145 0.9852

# %%
i_offset, j_offset = 20, 20
N_pic = 28
for batch_idx, (data, target) in enumerate(data_loader):
    data_28 = data[-1][-1]
    mnist_fullfield(data_28, i_offset, j_offset, figure_type='128')
    mnist_fullfield(data_28, i_offset, j_offset, figure_type='cmap')
    accuracy_fullfield(accuracy, i_offset, j_offset, figure_type='colliculus')
    break

# %%
for lr_ in lr*np.logspace(-1, 1, 9, base=10):
    net = Net(n_feature=N_theta*N_azimuth*N_eccentricity*N_phase, n_hidden1=n_hidden1, n_hidden2=n_hidden2, n_output=N_azimuth*N_eccentricity)
    optimizer = torch.optim.SGD(net.parameters(), lr=lr_)
    loss_func = torch.nn.BCEWithLogitsLoss()

    print('Training model... with lr=', '%.3f' % lr_)
    N_epochs = 3
    for epoch in range(N_epochs):                       #max number of training epochs
        train(net, minibatch_size, optimizer=optimizer) #starting the learning
# Out:
# Training model... with lr= 0.002
# Starting training...
# [0/60000] Loss: 0.7260284423828125 Time: 0.10 mn
# [10000/60000] Loss: 0.6655616760253906 Time: 7.46 mn
# [20000/60000] Loss: 0.6141806840896606 Time: 15.09 mn
# [30000/60000] Loss: 0.563962459564209 Time: 22.37 mn
# [40000/60000] Loss: 0.513530969619751 Time: 29.67 mn
# [50000/60000] Loss: 0.4735986292362213 Time: 36.94 mn
# Starting training...
# [0/60000] Loss: 0.4346146583557129 Time: 0.07 mn
# [10000/60000] Loss: 0.4142405092716217 Time: 7.43 mn
# [20000/60000] Loss: 0.40026938915252686 Time: 15.33 mn
# [30000/60000] Loss: 0.38856127858161926 Time: 24.67 mn
# [40000/60000] Loss: 0.38268521428108215 Time: 33.45 mn
# [50000/60000] Loss: 0.37848716974258423 Time: 40.59 mn
# Starting training...
# [0/60000] Loss: 0.38029518723487854 Time: 0.08 mn
# [10000/60000] Loss: 0.3775303363800049 Time: 6.99 mn
# [20000/60000] Loss: 0.3741234838962555 Time: 13.85 mn
# [30000/60000] Loss: 0.37681305408477783 Time: 20.92 mn
# [40000/60000] Loss: 0.3762131631374359 Time: 27.76 mn
# [50000/60000] Loss: 0.37110263109207153 Time: 34.54 mn
# Training model... with lr= 0.003
# Starting training...
# [0/60000] Loss: 0.7251732349395752 Time: 0.06 mn
# [10000/60000] Loss: 0.6256107091903687 Time: 5.59 mn
# [20000/60000] Loss: 0.5406519174575806 Time: 11.28 mn
# [30000/60000] Loss: 0.4650321304798126 Time: 16.95 mn
# [40000/60000] Loss: 0.41360440850257874 Time: 22.42 mn
