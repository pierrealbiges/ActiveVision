# %% [markdown]
# From https://pytorch.org/docs/0.3.1/nn.html?highlight=crossentropy#bcewithlogitsloss
#
# This loss combines a Sigmoid layer and the BCELoss in one single class. This version is more numerically stable than using a plain Sigmoid followed by a BCELoss as, by combining the operations into one layer, we take advantage of the log-sum-exp trick for numerical stability.
#
# The loss can be described as:
# ℓ(x,y)=L={l1,…,lN}⊤,ln=−wn[tn⋅logσ(xn)+(1−tn)⋅log(1−σ(xn))],
#
# where N
#
# is the batch size. If reduce is True, then
# ℓ(x,y)={mean(L),sum(L),ifsize_average=True,ifsize_average=False.
#
# This is used for measuring the error of a reconstruction in for example an auto-encoder. Note that the targets t[i] should be numbers between 0 and 1.
# Parameters:
#
#     weight (Tensor, optional) – a manual rescaling weight given to the loss of each batch element. If given, has to be a Tensor of size “nbatch”.
#     size_average – By default, the losses are averaged over observations for each minibatch. However, if the field size_average is set to False, the losses are instead summed for each minibatch. Default: True

# %%
from Where import *
# Out:
# Loading accuracy... min, max= 0.0145 0.9852
# n_hidden1 80  / n_hidden2 200

# %% [markdown]
# ## Réseau de neurones

# %% [markdown]
# ### Lancer l'apprentissage ou charger les données

# %%
path = '2018-05-23_classification_BCELoss.pt'

# %%
print('Loading file', path)
net.load_state_dict(torch.load(path))
# Out:
# Loading file 2018-05-23_classification_BCELoss.pt

# %% [markdown]
# ### Lancer l'évaluation

# %%
N_test = 42

for _ in range(N_test):
    eval_sacc()
    plt.show()
# Out:
# Stimulus position: (-17,-25)
# Position prediction: (2.0,5.0)
# **************************************************
# Stimulus position: (-11,25)
# Position prediction: (-9.0,-5.0)
# **************************************************
# Stimulus position: (5,6)
# Position prediction: (4.0,7.0)
# **************************************************
# Stimulus position: (-6,0)
# Position prediction: (-7.0,-3.0)
# **************************************************
# Stimulus position: (-2,17)
# Position prediction: (-4.0,14.0)
# **************************************************
# Stimulus position: (-3,3)
# Position prediction: (-4.0,-1.0)
# **************************************************
# Stimulus position: (12,0)
# Position prediction: (10.0,1.0)
# **************************************************
# Stimulus position: (0,-4)
# Position prediction: (1.0,-7.0)
# **************************************************
# Stimulus position: (1,-1)
# Position prediction: (2.0,-5.0)
# **************************************************
# Stimulus position: (8,-15)
# Position prediction: (4.0,-14.0)
# **************************************************
# Stimulus position: (10,-1)
# Position prediction: (10.0,-1.0)
# **************************************************
# Stimulus position: (7,-4)
# Position prediction: (7.0,-3.0)
# **************************************************
# Stimulus position: (-11,19)
# Position prediction: (7.0,1.0)
# **************************************************
# Stimulus position: (-5,-4)
# Position prediction: (-7.0,-3.0)
# **************************************************
# Stimulus position: (11,5)
# Position prediction: (11.0,5.0)
# **************************************************
# Stimulus position: (-2,-19)
# Position prediction: (-2.0,-21.0)
# **************************************************
# Stimulus position: (10,-6)
# Position prediction: (6.0,-8.0)
# **************************************************
# Stimulus position: (11,-8)
# Position prediction: (3.0,-7.0)
# **************************************************
# Stimulus position: (-1,3)
# Position prediction: (1.0,4.0)
# **************************************************
# Stimulus position: (-11,-20)
# Position prediction: (2.0,-7.0)
# **************************************************
# Stimulus position: (1,8)
# Position prediction: (-1.0,9.0)
# **************************************************
# Stimulus position: (0,3)
# Position prediction: (-4.0,1.0)
# **************************************************
# Stimulus position: (-1,7)
# Position prediction: (-5.0,7.0)
# **************************************************
# Stimulus position: (2,-3)
# Position prediction: (2.0,-7.0)
# **************************************************
# Stimulus position: (1,10)
# Position prediction: (-1.0,7.0)
# **************************************************
# Stimulus position: (-5,0)
# Position prediction: (-6.0,-3.0)
# **************************************************
# Stimulus position: (6,4)
# Position prediction: (3.0,6.0)
# **************************************************
# Stimulus position: (7,6)
# Position prediction: (7.0,2.0)
# **************************************************
# Stimulus position: (-10,-1)
# Position prediction: (-9.0,-4.0)
# **************************************************
# Stimulus position: (-4,10)
# Position prediction: (-2.0,7.0)
# **************************************************
# Stimulus position: (-10,-12)
# Position prediction: (-28.0,8.0)
# **************************************************
# Stimulus position: (-11,-23)
# Position prediction: (8.0,10.0)
# **************************************************
# Stimulus position: (-10,-5)
# Position prediction: (-9.0,-5.0)
# **************************************************
# Stimulus position: (10,19)
# Position prediction: (9.0,11.0)
# **************************************************
# Stimulus position: (12,10)
# Position prediction: (10.0,10.0)
# **************************************************
# Stimulus position: (4,0)
# Position prediction: (3.0,-4.0)
# **************************************************
# Stimulus position: (-6,2)
# Position prediction: (-5.0,2.0)
# **************************************************
# Stimulus position: (-14,-19)
# Position prediction: (1.0,-20.0)
# **************************************************
# Stimulus position: (-20,1)
# Position prediction: (-18.0,-9.0)
# **************************************************
# Stimulus position: (-1,-2)
# Position prediction: (2.0,-5.0)
# **************************************************
# Stimulus position: (-2,-1)
# Position prediction: (-4.0,1.0)
# **************************************************
# Stimulus position: (-7,17)
# Position prediction: (-5.0,13.0)
# **************************************************

# %%
for _ in range(N_test):
    eval_sacc(fig_type='log')
    plt.show()
# Out:
# Stimulus position: (-5,3)
# Loading pred_data... min, max= 0.016252505 0.85449165
# a_data position (log_r, azimuth) = (0.17428584550970905,1.0303768265243125)
# **************************************************
# Stimulus position: (2,8)
# Loading pred_data... min, max= 0.0027992905 0.8938825
# a_data position (log_r, azimuth) = (0.2436005635657036,-0.24497866312686414)
# **************************************************
# Stimulus position: (8,0)
# Loading pred_data... min, max= 0.017133294 0.77294475
# a_data position (log_r, azimuth) = (0.23753810138406017,-1.5707963267948966)
# **************************************************
# Stimulus position: (6,2)
# Loading pred_data... min, max= 0.0031520324 0.98138106
# a_data position (log_r, azimuth) = (0.19053773845948663,-1.2490457723982544)
# **************************************************
# Stimulus position: (1,0)
# Loading pred_data... min, max= 0.03793385 0.77018684
# a_data position (log_r, azimuth) = (-0.17835020695190695,-1.5707963267948966)
# **************************************************
# Stimulus position: (-4,12)
# Loading pred_data... min, max= 0.010091959 0.5612542
# a_data position (log_r, azimuth) = (0.3291671745714757,0.3217505543966422)
# **************************************************
# Stimulus position: (-16,5)
# Loading pred_data... min, max= 0.003983371 0.21499594
# a_data position (log_r, azimuth) = (0.38548525998146754,1.2679114584199251)
# **************************************************
# Stimulus position: (-6,6)
# Loading pred_data... min, max= 0.0027306732 0.6655659
# a_data position (log_r, azimuth) = (0.24931640494969842,0.7853981633974483)
# **************************************************
# Stimulus position: (-1,13)
# Loading pred_data... min, max= 0.015384131 0.37817028
# a_data position (log_r, azimuth) = (0.3352296367531191,0.07677189126977804)
# **************************************************
# Stimulus position: (-20,-8)
# Loading pred_data... min, max= 0.023012957 0.06305878
# a_data position (log_r, azimuth) = (0.4356382482707185,-1.1902899496825317)
# **************************************************
# Stimulus position: (15,-8)
# Loading pred_data... min, max= 0.005926657 0.20201021
# a_data position (log_r, azimuth) = (0.3882924618593362,1.0808390005411683)
# **************************************************
# Stimulus position: (14,4)
# Loading pred_data... min, max= 0.0069306684 0.40181252
# a_data position (log_r, azimuth) = (0.3573084205152942,-1.2924966677897853)
# **************************************************
# Stimulus position: (11,-12)
# Loading pred_data... min, max= 0.008514684 0.2488322
# a_data position (log_r, azimuth) = (0.3796227756467152,0.7419472680059175)
# **************************************************
# Stimulus position: (12,-22)
# Loading pred_data... min, max= 0.01876536 0.06298177
# a_data position (log_r, azimuth) = (0.46590380969491285,0.49934672168013006)
# **************************************************
# Stimulus position: (2,-5)
# Loading pred_data... min, max= 0.0010164392 0.9707081
# a_data position (log_r, azimuth) = (0.15837937604674024,0.3805063771123649)
# **************************************************
# Stimulus position: (11,-2)
# Loading pred_data... min, max= 0.007755133 0.51195616
# a_data position (log_r, azimuth) = (0.30448116677832304,1.3909428270024184)
# **************************************************
# Stimulus position: (-11,-17)
# Loading pred_data... min, max= 0.0050142487 0.05838494
# a_data position (log_r, azimuth) = (0.42326550901792825,-0.5743048301747018)
# **************************************************
# Stimulus position: (6,-20)
# Loading pred_data... min, max= 0.011369124 0.055204336
# a_data position (log_r, azimuth) = (0.42941401738299645,0.2914567944778671)
# **************************************************
# Stimulus position: (0,4)
# Loading pred_data... min, max= 0.010757761 0.8919439
# a_data position (log_r, azimuth) = (0.0989086652720712,0.0)
# **************************************************
# Stimulus position: (-1,-7)
# Loading pred_data... min, max= 0.0063189557 0.66633284
# a_data position (log_r, azimuth) = (0.2128520935909075,-0.1418970546041639)
# **************************************************
# Stimulus position: (-2,11)
# Loading pred_data... min, max= 0.013351089 0.3728133
# a_data position (log_r, azimuth) = (0.30448116677832304,0.17985349979247828)
# **************************************************
# Stimulus position: (1,-14)
# Loading pred_data... min, max= 0.0026587003 0.12711784
# a_data position (log_r, azimuth) = (0.3499701659218918,0.07130746478529032)
# **************************************************
# Stimulus position: (20,11)
# Loading pred_data... min, max= 0.0051514255 0.065808475
# a_data position (log_r, azimuth) = (0.44722479722342956,-1.067953115867036)
# **************************************************
# Stimulus position: (5,4)
# Loading pred_data... min, max= 0.00091137807 0.98899406
# a_data position (log_r, azimuth) = (0.19300699971852375,-0.8960553845713439)
# **************************************************
# Stimulus position: (14,-10)
# Loading pred_data... min, max= 0.0010956216 0.30675808
# a_data position (log_r, azimuth) = (0.39068573848049903,0.9505468408120751)
# **************************************************
# Stimulus position: (-1,-6)
# Loading pred_data... min, max= 0.0021277212 0.7532805
# a_data position (log_r, azimuth) = (0.18274158431251541,-0.16514867741462683)
# **************************************************
# Stimulus position: (-1,0)
# Loading pred_data... min, max= 0.017597554 0.77433795
# a_data position (log_r, azimuth) = (-0.17835020695190695,1.5707963267948966)
# **************************************************
# Stimulus position: (11,-3)
# Loading pred_data... min, max= 0.029687725 0.29470026
# a_data position (log_r, azimuth) = (0.3084032380936512,1.3045442776439713)
# **************************************************
# Stimulus position: (11,13)
# Loading pred_data... min, max= 0.018881211 0.20104644
# a_data position (log_r, azimuth) = (0.38863788534614496,-0.7022569315090071)
# **************************************************
# Stimulus position: (-18,-14)
# Loading pred_data... min, max= 0.011155322 0.04065168
# a_data position (log_r, azimuth) = (0.4470326742056403,-0.9097531579442097)
# **************************************************
# Stimulus position: (0,4)
# Loading pred_data... min, max= 0.013057168 0.9205663
# a_data position (log_r, azimuth) = (0.0989086652720712,0.0)
# **************************************************
# Stimulus position: (1,1)
# Loading pred_data... min, max= 0.0049714595 0.9000615
# a_data position (log_r, azimuth) = (-0.10903548889591241,-0.7853981633974483)
# **************************************************
# Stimulus position: (-4,15)
# Loading pred_data... min, max= 0.008653451 0.299555
# a_data position (log_r, azimuth) = (0.3701294863971585,0.26060239174734096)
# **************************************************
# Stimulus position: (13,16)
# Loading pred_data... min, max= 0.006598093 0.0498238
# a_data position (log_r, azimuth) = (0.42685870994053465,-0.6823165548747481)
# **************************************************
# Stimulus position: (-2,-17)
# Loading pred_data... min, max= 0.017272497 0.11135941
# a_data position (log_r, azimuth) = (0.3896670539497997,-0.11710874456686428)
# **************************************************
# Stimulus position: (2,-8)
# Loading pred_data... min, max= 0.001174811 0.8111341
# a_data position (log_r, azimuth) = (0.2436005635657036,0.24497866312686414)
# **************************************************
# Stimulus position: (-2,4)
# Loading pred_data... min, max= 0.0062940493 0.98261535
# a_data position (log_r, azimuth) = (0.12122302040349209,0.46364760900080615)
# **************************************************
# Stimulus position: (0,7)
# Loading pred_data... min, max= 0.005035382 0.94044
# a_data position (log_r, azimuth) = (0.21083182285915558,0.0)
# **************************************************
# Stimulus position: (4,-1)
# Loading pred_data... min, max= 0.008147816 0.95451313
# a_data position (log_r, azimuth) = (0.10497112745371451,1.3258176636680326)
# **************************************************
# Stimulus position: (-15,6)
# Loading pred_data... min, max= 0.011238742 0.24676307
# a_data position (log_r, azimuth) = (0.37810183378036233,1.1902899496825317)
# **************************************************
# Stimulus position: (8,-11)
# Loading pred_data... min, max= 0.009267515 0.4306511
# a_data position (log_r, azimuth) = (0.3436853755559255,0.628796286415433)
# **************************************************
# Stimulus position: (6,3)
# Loading pred_data... min, max= 0.014878961 0.8759298
# a_data position (log_r, azimuth) = (0.202316042025125,-1.1071487177940906)
# **************************************************
