# %%
# %load_ext autoreload
# %autoreload 2

# %%
from Where import *
# Out:
# Loading accuracy... min, max= 0.0145 0.9852
# n_hidden1 80  / n_hidden2 200

# %%
print('mean', mean, ', std', std)
# Out:
# mean 0.0 , std 0.3

# %%
data_loader = get_data_loader(mean=mean, std=std, minibatch_size=minibatch_size)

net = Net(n_feature=N_theta*N_azimuth*N_eccentricity*N_phase, n_hidden1=n_hidden1, n_hidden2=n_hidden2, n_output=N_azimuth*N_eccentricity)
optimizer = torch.optim.SGD(net.parameters(), lr=10*lr)
loss_func = torch.nn.SmoothL1Loss()

print('Training model... with lr=', '%.3f' % lr)
N_epochs = 1
for epoch in range(N_epochs):                       #max number of training epochs
    train(net, minibatch_size, optimizer=optimizer) #starting the learning
# Out:
# Training model... with lr= 0.050
# Starting training...
# [0/60000] Loss: 0.6960577368736267 Time: 0.06 mn
# [10000/60000] Loss: 0.3878743648529053 Time: 6.68 mn
# [20000/60000] Loss: 0.3841880261898041 Time: 13.59 mn
# [30000/60000] Loss: 0.37335461378097534 Time: 19.63 mn
# [40000/60000] Loss: 0.37028777599334717 Time: 26.15 mn
# [50000/60000] Loss: 0.3672972619533539 Time: 32.62 mn

# %%
N_test = 10

for _ in range(N_test):
    eval_sacc()
    plt.show()
# Out:
# n_hidden1 80  / n_hidden2 200
# Stimulus position: (-16,6)
# Position prediction: (-18.0,10.0)
# **************************************************
# Stimulus position: (13,-3)
# Position prediction: (-9.0,18.0)
# **************************************************
# Stimulus position: (6,-1)
# Position prediction: (-11.0,17.0)
# **************************************************
# Stimulus position: (0,16)
# Position prediction: (-9.0,4.0)
# **************************************************
# Stimulus position: (0,-4)
# Position prediction: (-8.0,-6.0)
# **************************************************
# Stimulus position: (-7,-17)
# Position prediction: (-4.0,9.0)
# **************************************************
# Stimulus position: (3,-6)
# Position prediction: (1.0,-9.0)
# **************************************************
# Stimulus position: (0,-20)
# Position prediction: (-9.0,2.0)
# **************************************************
# Stimulus position: (11,11)
# Position prediction: (-9.0,-6.0)
# **************************************************
# Stimulus position: (-13,-7)
# Position prediction: (-4.0,9.0)
# **************************************************
