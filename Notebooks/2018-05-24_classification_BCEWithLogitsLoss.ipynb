# %% [markdown]
# From https://pytorch.org/docs/0.3.1/nn.html?highlight=crossentropy#bcewithlogitsloss
#
# This loss combines a Sigmoid layer and the BCELoss in one single class. This version is more numerically stable than using a plain Sigmoid followed by a BCELoss as, by combining the operations into one layer, we take advantage of the log-sum-exp trick for numerical stability.
#
# The loss can be described as:
# ℓ(x,y)=L={l1,…,lN}⊤,ln=−wn[tn⋅logσ(xn)+(1−tn)⋅log(1−σ(xn))],
#
# where N
#
# is the batch size. If reduce is True, then
# ℓ(x,y)={mean(L),sum(L),ifsize_average=True,ifsize_average=False.
#
# This is used for measuring the error of a reconstruction in for example an auto-encoder. Note that the targets t[i] should be numbers between 0 and 1.
# Parameters:
#
#     weight (Tensor, optional) – a manual rescaling weight given to the loss of each batch element. If given, has to be a Tensor of size “nbatch”.
#     size_average – By default, the losses are averaged over observations for each minibatch. However, if the field size_average is set to False, the losses are instead summed for each minibatch. Default: True

# %%
from Where import *
# Out:
# Loading accuracy...
# [[0.0974 0.0974 0.0974 ... 0.0974 0.0974 0.0974]
#  [0.0974 0.0974 0.0974 ... 0.0974 0.0974 0.0974]
#  [0.0974 0.0974 0.0974 ... 0.0974 0.0974 0.0974]
#  ...
#  [0.0974 0.0974 0.0974 ... 0.0974 0.0974 0.0974]
#  [0.0974 0.0974 0.0974 ... 0.0974 0.0974 0.0974]
#  [0.0974 0.0974 0.0974 ... 0.0974 0.0974 0.0974]]

# %% [markdown]
# ## Réseau de neurones

# %% [markdown]
# ### Lancer l'apprentissage ou charger les données

# %%
path = '2018-05-23_classification_BCELoss.pt'

# %%
# !ls -l {path}
#!rm {path}
# Out:
# ls: 2018-05-23_classification_BCELoss.pt: No such file or directory

# %%
if os.path.isfile(path):
    net.load_state_dict(torch.load(path))
    print('Loading file', path)
else:
    print('Training model...')
    N_epochs = 3
    for epoch in range(N_epochs):          #max number of training epochs
        net = train(net, sample_size)                 #starting the learning
        torch.save(net.state_dict(), path) #save the neural network state
        print('Model saved at', path)
# Out:
# Training model...
# Starting training...
# [0/60000] Loss: 1.1100420951843262 Time: 0.02 mn
# [10000/60000] Loss: 0.39031681418418884 Time: 1.72 mn
# [20000/60000] Loss: 0.3779076337814331 Time: 3.79 mn
# [30000/60000] Loss: 0.3714160919189453 Time: 10.13 mn
# [40000/60000] Loss: 0.3673526644706726 Time: 16.52 mn
# [50000/60000] Loss: 0.36472487449645996 Time: 22.94 mn
# Model saved at 2018-05-23_classification_BCELoss.pt
# Starting training...
# [0/60000] Loss: 0.3635323643684387 Time: 0.07 mn
# [10000/60000] Loss: 0.36108338832855225 Time: 6.39 mn
# [20000/60000] Loss: 0.3622414767742157 Time: 12.73 mn
# [30000/60000] Loss: 0.35882824659347534 Time: 19.03 mn
# [40000/60000] Loss: 0.35863015055656433 Time: 25.39 mn
# [50000/60000] Loss: 0.35864460468292236 Time: 31.75 mn
# Model saved at 2018-05-23_classification_BCELoss.pt
# Starting training...
# [0/60000] Loss: 0.3581632375717163 Time: 0.06 mn
# [10000/60000] Loss: 0.35698866844177246 Time: 6.35 mn
# [20000/60000] Loss: 0.35668089985847473 Time: 12.77 mn
# [30000/60000] Loss: 0.35763734579086304 Time: 18.98 mn
# [40000/60000] Loss: 0.35662975907325745 Time: 25.22 mn
# [50000/60000] Loss: 0.35687920451164246 Time: 31.47 mn
# Model saved at 2018-05-23_classification_BCELoss.pt

# %% [markdown]
# ### Lancer l'évaluation

# %%
N_test = 10

for _ in range(N_test):
    eval_sacc()
    plt.show()
# Out:
# Stimulus position: (-7,-6)
# Position prediction: (0.0,50.0)
# Stimulus position after saccade: (-7.0, -56.0)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-309324be7cf1> in <module>()
#       2
#       3 for _ in range(N_test):
# ----> 4     eval_sacc()
#       5     plt.show()
#
# ~/research/Shared/2018_PA_StageB/ActiveVision/Notebooks/Where.py in eval_sacc(vsize, asize, N_pic, sacc_lim, fovea_size, fig_type)
#     297             minmax(np.random.randn()*10, 35)), int(minmax(np.random.randn()*10, 35))
#     298         print('Stimulus position: ({},{})'.format(i_offset, j_offset))
# --> 299         a_data_in_fovea = False
#     300         sacc_count = 0
#     301
#
# ~/research/Shared/2018_PA_StageB/ActiveVision/Notebooks/Where.py in couples(data, i_offset, j_offset, device)
#     107                 data_128 + randomized_perlin_noise())
#     108     else:
# --> 109         data_LP = phi_vector @ np.ravel(data_128)
#     110     return data_LP
#     111
#
# ~/research/Shared/2018_PA_StageB/ActiveVision/Notebooks/Where.py in mnist_128(data, i_offset, j_offset, N_pic, N_stim, noise, noise_type)
#      92
#      93
# ---> 94 def mnist_128(data, i_offset, j_offset, N_pic=128, N_stim=28, noise=True, noise_type='MotionCloud'):
#      95     center = (N_pic-N_stim)//2
#      96     #data_128 = np.zeros((N_pic, N_pic))
#
# ValueError: could not broadcast input array from shape (28,28) into shape (28,0)

# %%
for _ in range(N_test):
    eval_sacc(fig_type='log')
    plt.show()
# Out:
# Stimulus position: (3,-6)
# a_data position (log_r, theta) = (0.202316042025125,0.46364760900080615)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-36b761319df1> in <module>()
#       1 for _ in range(N_test):
# ----> 2     eval_sacc(fig_type='log')
#       3     plt.show()
#
# ~/research/Shared/2018_PA_StageB/ActiveVision/Notebooks/Where.py in eval_sacc(vsize, asize, N_pic, sacc_lim, fovea_size, fig_type)
#     365                 else:
#     366                     theta_a_data = np.sign(-i_offset) * np.pi/2
# --> 367                 print('a_data position (log_r, theta) = ({},{})'.format(
#     368                     log_r_a_data, theta_a_data))
#     369                 log_r, theta = np.meshgrid(np.linspace(
#
# /usr/local/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1853                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1854                         RuntimeWarning, stacklevel=2)
# -> 1855             return func(ax, *args, **kwargs)
#    1856
#    1857         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# /usr/local/lib/python3.6/site-packages/matplotlib/axes/_axes.py in pcolor(self, *args, **kwargs)
#    5730         vmax = kwargs.pop('vmax', None)
#    5731
# -> 5732         X, Y, C = self._pcolorargs('pcolor', *args, allmatch=False)
#    5733         Ny, Nx = X.shape
#    5734
#
# /usr/local/lib/python3.6/site-packages/matplotlib/axes/_axes.py in _pcolorargs(funcname, *args, **kw)
#    5574                 raise TypeError('Dimensions of C %s are incompatible with'
#    5575                                 ' X (%d) and/or Y (%d); see help(%s)' % (
# -> 5576                                     C.shape, Nx, Ny, funcname))
#    5577             C = C[:Ny - 1, :Nx - 1]
#    5578         C = cbook.safe_masked_invalid(C)
#
# TypeError: Dimensions of C (5, 12) are incompatible with X (6) and/or Y (13); see help(pcolor)
