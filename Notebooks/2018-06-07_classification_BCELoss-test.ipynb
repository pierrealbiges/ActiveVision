# %%
from Where import *
# Out:
# Loading accuracy... min, max= 0.0145 0.9852
# n_hidden1 80  / n_hidden2 200

# %% [markdown]
# ## Réseau de neurones

# %% [markdown]
# ### Lancer l'apprentissage ou charger les données

# %%
path = '2018-05-23_classification_BCELoss.pt'

# %%
path = '2018-06-07_classification_BCELoss.pt'

# %%
# !ls -l {path}
# Out:
# -rw-r--r--  1 laurentperrinet  staff  511993 Jun  7 17:48 2018-05-23_classification_BCELoss.pt

# %%
print('Loading file', path)

net.load_state_dict(torch.load(path))
# Out:
# Loading file 2018-05-23_classification_BCELoss.pt

# %% [markdown]
# ### Lancer l'évaluation

# %%
N_test = 10

for _ in range(N_test):
    eval_sacc()
    plt.show()
# Out:
# Stimulus position: (-12,8)
# Position prediction: (-12.0,5.0)
# **************************************************
# Stimulus position: (-2,-1)
# Position prediction: (-6.0,-1.0)
# **************************************************
# Stimulus position: (4,20)
# Position prediction: (-9.0,27.0)
# **************************************************
# Stimulus position: (-2,-2)
# Position prediction: (-6.0,-2.0)
# **************************************************
# Stimulus position: (4,14)
# Position prediction: (4.0,13.0)
# **************************************************
# Stimulus position: (-2,-2)
# Position prediction: (-7.0,-2.0)
# **************************************************
# Stimulus position: (-4,-10)
# Position prediction: (-5.0,-12.0)
# **************************************************
# Stimulus position: (0,13)
# Position prediction: (-1.0,11.0)
# **************************************************
# Stimulus position: (3,17)
# Position prediction: (5.0,13.0)
# **************************************************
# Stimulus position: (8,10)
# Position prediction: (5.0,7.0)
# **************************************************

# %%
for _ in range(N_test):
    eval_sacc(fig_type='log')
    plt.show()
# Out:
# Stimulus position: (-10,8)
# Loading pred_data... min, max= 0.0025781218 0.29495445
# a_data position (log_r, azimuth) = (0.33163643583051283,0.8960553845713439)
# **************************************************
# Stimulus position: (-2,0)
# Loading pred_data... min, max= 0.0048119053 0.93134534
# a_data position (log_r, azimuth) = (-0.039720770839917874,1.5707963267948966)
# **************************************************
# Stimulus position: (-6,15)
# Loading pred_data... min, max= 0.0015748101 0.41508833
# a_data position (log_r, azimuth) = (0.37810183378036233,0.3805063771123649)
# **************************************************
# Stimulus position: (5,-12)
# Loading pred_data... min, max= 0.0023995007 0.23658729
# a_data position (log_r, azimuth) = (0.3346396645404004,0.39479111969976155)
# **************************************************
# Stimulus position: (20,-8)
# Loading pred_data... min, max= 0.016174795 0.09010164
# a_data position (log_r, azimuth) = (0.4356382482707185,1.1902899496825317)
# **************************************************
# Stimulus position: (-11,6)
# Loading pred_data... min, max= 0.014106588 0.2711167
# a_data position (log_r, azimuth) = (0.32727437358292377,1.0714496051147666)
# **************************************************
# Stimulus position: (-1,-9)
# Loading pred_data... min, max= 0.012208081 0.3371601
# a_data position (log_r, azimuth) = (0.2623217177745183,-0.11065722117389563)
# **************************************************
# Stimulus position: (-16,-23)
# Loading pred_data... min, max= 0.0005897693 0.015477169
# a_data position (log_r, azimuth) = (0.48821816482633384,-0.6078019961139604)
# **************************************************
# Stimulus position: (0,-1)
# Loading pred_data... min, max= 0.0012874661 0.9781917
# a_data position (log_r, azimuth) = (-0.17835020695190695,-0.0)
# **************************************************
# Stimulus position: (9,0)
# Loading pred_data... min, max= 0.027372984 0.537498
# a_data position (log_r, azimuth) = (0.2610947085153368,-1.5707963267948966)
# **************************************************
