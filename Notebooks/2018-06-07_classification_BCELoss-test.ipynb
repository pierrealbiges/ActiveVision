# %%
from Where import *
# Out:
# Loading accuracy... min, max= 0.0145 0.9852
# n_hidden1 80  / n_hidden2 200

# %% [markdown]
# ## Réseau de neurones

# %% [markdown]
# ### Lancer l'apprentissage ou charger les données

# %%
path = '2018-05-23_classification_BCELoss.pt'

# %%
path = '2018-06-07_classification_BCELoss.pt'

# %%
# !ls -l {path}
# Out:
# -rw-r--r--  1 laurentperrinet  staff  511993 Jun 12 09:13 2018-06-07_classification_BCELoss.pt

# %%
print('Loading file', path)

net.load_state_dict(torch.load(path))
# Out:
# Loading file 2018-06-07_classification_BCELoss.pt

# %% [markdown]
# ### Lancer l'évaluation

# %%
N_test = 10

for _ in range(N_test):
    eval_sacc()
    plt.show()
# Out:
# Stimulus position: (19,4)
# Position prediction: (15.0,3.0)
# **************************************************
# Stimulus position: (10,-8)
# Position prediction: (11.0,-9.0)
# **************************************************
# Stimulus position: (-15,19)
# Position prediction: (-17.0,15.0)
# **************************************************
# Stimulus position: (5,0)
# Position prediction: (5.0,-2.0)
# **************************************************
# Stimulus position: (13,4)
# Position prediction: (12.0,4.0)
# **************************************************
# Stimulus position: (-3,-3)
# Position prediction: (-4.0,-3.0)
# **************************************************
# Stimulus position: (-4,-5)
# Position prediction: (-4.0,-5.0)
# **************************************************
# Stimulus position: (-8,2)
# Position prediction: (-10.0,1.0)
# **************************************************
# Stimulus position: (13,7)
# Position prediction: (13.0,5.0)
# **************************************************
# Stimulus position: (10,6)
# Position prediction: (9.0,5.0)
# **************************************************

# %%
for _ in range(N_test):
    eval_sacc(fig_type='log')
    plt.show()
# Out:
# Stimulus position: (12,-9)
# Loading pred_data... min, max= 0.025666961 0.32672456
# a_data position (log_r, azimuth) = (0.36325983326853495,0.9272952180016122)
# **************************************************
# Stimulus position: (4,8)
# Loading pred_data... min, max= 0.02535257 0.668926
# a_data position (log_r, azimuth) = (0.25985245651548117,-0.46364760900080615)
# **************************************************
# Stimulus position: (13,6)
# Loading pred_data... min, max= 0.040830262 0.35635376
# a_data position (log_r, azimuth) = (0.3539507909619337,-1.1383885512243588)
# **************************************************
# Stimulus position: (-2,-11)
# Loading pred_data... min, max= 0.023088995 0.3809843
# a_data position (log_r, azimuth) = (0.30448116677832304,-0.17985349979247828)
# **************************************************
# Stimulus position: (2,13)
# Loading pred_data... min, max= 0.04987891 0.3921446
# a_data position (log_r, azimuth) = (0.3369789524978708,-0.15264932839526518)
# **************************************************
# Stimulus position: (-7,-9)
# Loading pred_data... min, max= 0.02053781 0.3465824
# a_data position (log_r, azimuth) = (0.3084032380936512,-0.6610431688506869)
# **************************************************
# Stimulus position: (0,11)
# Loading pred_data... min, max= 0.021687714 0.44563693
# a_data position (log_r, azimuth) = (0.301228847607767,0.0)
# **************************************************
# Stimulus position: (-5,1)
# Loading pred_data... min, max= 0.030076854 0.7328746
# a_data position (log_r, azimuth) = (0.14745944685024115,1.373400766945016)
# **************************************************
# Stimulus position: (15,0)
# Loading pred_data... min, max= 0.019039052 0.31667385
# a_data position (log_r, azimuth) = (0.36325983326853495,-1.5707963267948966)
# **************************************************
# Stimulus position: (-4,4)
# Loading pred_data... min, max= 0.030798469 0.7545459
# a_data position (log_r, azimuth) = (0.16822338332806575,0.7853981633974483)
# **************************************************
