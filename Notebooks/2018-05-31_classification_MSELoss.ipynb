# %%
# %load_ext autoreload
# %autoreload 2

# %%
from Where_test_loss import *
# Out:
# Loading accuracy... min, max= 0.0145 0.9852

# %%
i_offset, j_offset = 20, 20
for batch_idx, (data, target) in enumerate(data_loader):
    data_28 = data[-1][-1]
    mnist_fullfield(data_28, i_offset, j_offset, figure_type='128')
    mnist_fullfield(data_28, i_offset, j_offset, figure_type='cmap')
    accuracy_fullfield(accuracy, i_offset, j_offset, figure_type='colliculus')
    break

# %% [raw]
# for lr_ in lr*np.logspace(-1, 1, 9, base=10):
#     net = Net(n_feature=N_theta*N_azimuth*N_eccentricity*N_phase, n_hidden1=n_hidden1, n_hidden2=n_hidden2, n_output=N_azimuth*N_eccentricity)
#     optimizer = torch.optim.SGD(net.parameters(), lr=lr_)
#     loss_func = torch.nn.SmoothL1Loss()
#
#     print('Training model... with lr=', '%.3f' % lr_)
#     N_epochs = 3
#     for epoch in range(N_epochs):                       #max number of training epochs
#         train(net, minibatch_size, optimizer=optimizer) #starting the learning
#     eval_sacc()
#     plt.show()

# %%
net = Net(n_feature=N_theta*N_azimuth*N_eccentricity*N_phase, n_hidden1=n_hidden1, n_hidden2=n_hidden2, n_output=N_azimuth*N_eccentricity)
optimizer = torch.optim.SGD(net.parameters(), lr=lr)
loss_func = torch.nn.SmoothL1Loss()

print('Training model... with lr=', '%.3f' % lr)
N_epochs = 3
for epoch in range(N_epochs):                       #max number of training epochs
    train(net, minibatch_size, optimizer=optimizer) #starting the learning
eval_sacc()
plt.show()
# Out:
# Training model... with lr= 0.016
# Starting training...
# [0/60000] Loss: 2.0970067977905273 Time: 0.05 mn
# [10000/60000] Loss: 0.03615475073456764 Time: 4.53 mn
# [20000/60000] Loss: 0.022464321926236153 Time: 8.09 mn
# [30000/60000] Loss: 0.020322976633906364 Time: 10.98 mn
# [40000/60000] Loss: 0.016931362450122833 Time: 13.86 mn
# [50000/60000] Loss: 0.015450832433998585 Time: 16.85 mn
# Starting training...
# [0/60000] Loss: 0.014156598597764969 Time: 0.03 mn
# [10000/60000] Loss: 0.012181573547422886 Time: 3.06 mn
# [20000/60000] Loss: 0.010307119227945805 Time: 6.08 mn
# [30000/60000] Loss: 0.00884526688605547 Time: 10.44 mn
# [40000/60000] Loss: 0.008009879849851131 Time: 13.53 mn
# [50000/60000] Loss: 0.0072380416095256805 Time: 16.60 mn
# Starting training...
# [0/60000] Loss: 0.0058645568788051605 Time: 0.03 mn
# [10000/60000] Loss: 0.005391309969127178 Time: 3.43 mn
# [20000/60000] Loss: 0.005762317217886448 Time: 7.85 mn
# [30000/60000] Loss: 0.00510133383795619 Time: 12.28 mn
# [40000/60000] Loss: 0.005353823304176331 Time: 16.69 mn
# [50000/60000] Loss: 0.00474713696166873 Time: 20.72 mn
# Stimulus position: (0,6)
# Position prediction: (18.0,-9.0)
# **************************************************

# %%
N_test = 10

for _ in range(N_test):
    eval_sacc()
    plt.show()
# Out:
# Loading accuracy... min, max= 0.0145 0.9852
# Stimulus position: (5,-2)
# Position prediction: (7.0,-2.0)
# **************************************************
# Stimulus position: (-6,10)
# Position prediction: (-17.0,-12.0)
# **************************************************
# Stimulus position: (-9,1)
# Position prediction: (7.0,-2.0)
# **************************************************
# Stimulus position: (1,7)
# Position prediction: (7.0,-2.0)
# **************************************************
# Stimulus position: (-17,-20)
# Position prediction: (9.0,4.0)
# **************************************************
# Stimulus position: (-8,1)
# Position prediction: (7.0,-2.0)
# **************************************************
# Stimulus position: (0,-14)
# Position prediction: (-3.0,14.0)
# **************************************************
# Stimulus position: (-4,-6)
# Position prediction: (7.0,-2.0)
# **************************************************
# Stimulus position: (10,4)
# Position prediction: (7.0,-2.0)
# **************************************************
# Stimulus position: (-5,4)
# Position prediction: (-1.0,-10.0)
# **************************************************
