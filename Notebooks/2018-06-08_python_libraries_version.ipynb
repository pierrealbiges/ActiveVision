# %% [markdown]
# Pour une question de reproductibilité, ce notebook rassemble l'ensemble des librairies python installées sur la machine réalisant les simulations, à la date indiquée dans son titre.

# %%
# !pip3 freeze
# Out:
# apturl==0.5.2
# beautifulsoup4==4.4.1
# bleach==2.1.3
# blinker==1.3
# Brlapi==0.6.4
# chardet==2.3.0
# checkbox-support==0.22
# command-not-found==0.3
# cryptography==1.2.3
# cycler==0.10.0
# decorator==4.0.6
# defer==1.0.6
# easydict==1.7
# entrypoints==0.2.3
# feedparser==5.1.3
# guacamole==0.9.2
# html5lib==1.0.1
# httplib2==0.9.1
# idna==2.0
# imageio==2.3.0
# ipykernel==4.8.2
# ipython==6.2.1
# ipython-genutils==0.2.0
# ipywidgets==7.1.2
# jedi==0.11.1
# Jinja2==2.8
# joblib==0.9.4
# jsonschema==2.6.0
# jupyter==1.0.0
# jupyter-client==5.2.3
# jupyter-console==5.2.0
# jupyter-core==4.4.0
# kiwisolver==1.0.1
# language-selector==0.1
# LogGabor==20171205
# louis==2.6.4
# lxml==3.5.0
# Mako==1.0.3
# MarkupSafe==0.23
# matplotlib==2.2.2
# mistune==0.8.3
# MotionClouds==20171206
# nbconvert==5.3.1
# nbformat==4.4.0
# NeuroTools==0.3.1
# noise==1.2.2
# nose==1.3.7
# notebook==5.4.1
# numexpr==2.4.3
# numpy==1.14.3
# oauthlib==1.0.3
# onboard==1.2.0
# padme==1.1.1
# pandas==0.17.1
# ...
