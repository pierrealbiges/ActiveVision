# %%
# %load_ext autoreload
# %autoreload 2

# %%
from Where_test_loss import *
# Out:
# Loading accuracy... min, max= 0.0145 0.9852

# %%
i_offset, j_offset = 20, 20
N_pic = 28
for batch_idx, (data, target) in enumerate(data_loader):
    data_28 = data[-1][-1]
    mnist_fullfield(data_28, i_offset, j_offset, figure_type='128')
    mnist_fullfield(data_28, i_offset, j_offset, figure_type='cmap')
    accuracy_fullfield(accuracy, i_offset, j_offset, figure_type='colliculus')
    break

# %%
for lr_ in lr*np.logspace(-1, 1, 9, base=10):
    net = Net(n_feature=N_theta*N_azimuth*N_eccentricity*N_phase, n_hidden1=n_hidden1, n_hidden2=n_hidden2, n_output=N_azimuth*N_eccentricity)
    optimizer = torch.optim.SGD(net.parameters(), lr=lr_)
    loss_func = torch.nn.MSELoss()

    print('Training model... with lr=', '%.3f' % lr_)
    N_epochs = 2
    for epoch in range(N_epochs):                       #max number of training epochs
        train(net, minibatch_size, optimizer=optimizer) #starting the learning    
    eval_sacc()
    plt.show()
# Out:
# Training model... with lr= 0.002
# Starting training...
# [0/60000] Loss: 1.7795064449310303 Time: 0.02 mn
# [10000/60000] Loss: 0.2741148769855499 Time: 1.50 mn
# [20000/60000] Loss: 0.11356065422296524 Time: 3.03 mn
# [30000/60000] Loss: 0.08056092262268066 Time: 4.59 mn
# [40000/60000] Loss: 0.055803049355745316 Time: 7.18 mn
# [50000/60000] Loss: 0.051734115928411484 Time: 10.12 mn
# Starting training...
# [0/60000] Loss: 0.04450685530900955 Time: 0.04 mn
# [10000/60000] Loss: 0.03350648283958435 Time: 4.14 mn
# [20000/60000] Loss: 0.03246793895959854 Time: 8.47 mn
# [30000/60000] Loss: 0.028225673362612724 Time: 12.60 mn
# [40000/60000] Loss: 0.028986673802137375 Time: 16.68 mn
# [50000/60000] Loss: 0.023650608956813812 Time: 19.58 mn
# Stimulus position: (-7,8)
# Position prediction: (-33.0,23.0)
# **************************************************
# Training model... with lr= 0.003
# Starting training...
# [0/60000] Loss: 1.5688097476959229 Time: 0.03 mn
