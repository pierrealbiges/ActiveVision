# %% [markdown]
# ## Ce notebook contient les exercices du cours ["Introduction à l'apprentissage profond"](http://cedric.cnam.fr/vertigo/Cours/ml2/tpDeepLearning1.html) proposé par le CNAM.
# ### Pour les notes de cours, voir [DAUCE_W2](http://localhost:8888/notebooks/Documents/LabBooks/DAUCE-W2.ipynb).

# %%
# %matplotlib inline

# %% [markdown]
# ## Récupérer des données

# %%
from keras.datasets import mnist #Base de données avec 70.000 images de lettres manuscrites
# Mélanger les données et les diviser entre train et test
(X_train, Y_train), (X_test, Y_test) = mnist.load_data()

X_train = X_train.reshape(60000, 784)
X_train = X_train.astype('float32')
X_train /= 255

X_test = X_test.reshape(10000,784)
X_test = X_test.astype('float32')
X_test /= 255

print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')
# Out:
# Using Theano backend.
# Downloading data from https://s3.amazonaws.com/img-datasets/mnist.npz
# 11493376/11490434 [==============================] - 2s 0us/step
# 60000 train samples
# 10000 test samples

# %% [markdown]
# ## Exercice 0

# %%
# Récupérer 200 des images de X_train et les afficher
import matplotlib.pyplot as plt

#plt.use('TKAgg')
plt.figure(figsize=(7.195, 3.841), dpi=100)

for i in range(200):
    plt.subplot(10,20,i+1)
    plt.imshow(X_train[i,:].reshape([28,28]), cmap='gray')
    plt.axis('off')
plt.show()

# %% [markdown]
# ## Exercice 1
